# %% [markdown]
# <a href="https://colab.research.google.com/github/Kim-jong-hoon/week-4-4/blob/main/YOLO_V8_%EC%A7%81%EC%A0%91%EC%98%81%EC%83%81.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. 설치
# !pip install -q ultralytics opencv-python

# 2. 파일 업로드
from google.colab import files
uploaded = files.upload()

# 업로드한 동영상 경로 설정
video_path = list(uploaded.keys())[0]
print(f"업로드된 파일: {video_path}")

# 3. YOLO 모델 로드
from ultralytics import YOLO
import cv2

model = YOLO("yolov8n.pt")  # 가볍고 빠른 YOLOv8n 모델 사용

# 4. 영상 열고 탐지 수행 및 저장

# 동영상 읽기
cap = cv2.VideoCapture(video_path)

# 저장 설정
fps = cap.get(cv2.CAP_PROP_FPS)
w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter("result_video.mp4", fourcc, fps, (w, h))

# 프레임별로 YOLO 탐지 수행
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # YOLO 추론
    results = model(frame)
    annotated_frame = results[0].plot()  # 탐지 결과 시각화

    # 결과 저장
    out.write(annotated_frame)

cap.release()
out.release()
print("✅ 객체 탐지 완료: result_video.mp4 저장됨")

# 5. 결과 다운로드
from google.colab import files
files.download("result_video.mp4")
# Out:
#      <input type="file" id="files-c08d3751-9033-42de-87fc-8a3622b8a7bc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c08d3751-9033-42de-87fc-8a3622b8a7bc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
